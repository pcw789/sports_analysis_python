# %% [markdown]
# # OBP와 SLG

# %% [markdown]
# OBP = On-Base Percentage : 출루율
# SLG = Slugging Percentage : 장타율
#
# 옛날 야구 시장에서는 장타율이 선수(타자)의 실력을 입증하는 지표였다.
# 머니볼이라는 논문에서 타자의 출루율에 대한 분석이 이루어지면서 출루율이 중요한 지표가 되기 시작한다.
#
# 타자들의 출루율과 장타율이 팀의 승률과 얼마나 관계되어 있는지 확인해보자.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Teams = pd.read_excel("Game logs 1999-2003.xlsx")

# %%
Teams.head()
# Out:
#        date  game_number  day visitor visitor_lg  visitor_game_number home  \
# 0  19990404            0  Sun     COL         NL                    1  SDN
# 1  19990405            0  Mon     TBA         AL                    1  BAL
# 2  19990405            0  Mon     BOS         AL                    1  KCA
# 3  19990405            0  Mon     NYA         AL                    1  OAK
# 4  19990405            0  Mon     CHA         AL                    1  SEA
#
#   home_lg  home_game_number  visitor_score  ...  home_batter_7_name  \
# 0      NL                 1              8  ...        Ruben Rivera
# 1      AL                 1              7  ...        B.J. Surhoff
# 2      AL                 1              5  ...        Chad Kreuter
# 3      AL                 1              3  ...         Eric Chavez
# 4      AL                 1              8  ...          John Mabry
#
#    home_batter_7_pos home_batter_8_id home_batter_8_name  home_batter_8_pos  \
# 0                  8         gomec001        Chris Gomez                  6
# 1                  7         johnc002    Charles Johnson                  2
# 2                  2         sancr001        Rey Sanchez                  6
# 3                  5         hinca001         A.J. Hinch                  2
# 4                  7         davir002         Russ Davis                  5
#
#   home_batter_9_id home_batter_9_name  home_batter_9_pos  additional_info  \
# 0         ashba002         Andy Ashby                  1              NaN
# 1         reboj001      Jeff Reboulet                  4              NaN
# 2         feblc001      Carlos Febles                  4              NaN
# 3         tejam001      Miguel Tejada                  6              NaN
# 4         wilsd001         Dan Wilson                  2              NaN
#
#   acquisition
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           Y
#
# [5 rows x 161 columns]

# %%
Teams.shape
# Out:
# (12142, 161)

# %% [markdown]
# ### 각 팀의 연도별 승률, 출루율, 장타율을 계산하기 위해 데이터 가공

# %%
Teams['Year'] = Teams['date'].astype(str).str[0:4]
Teams['Year'] = Teams['Year'].astype(int)
Teams.head()
# Out:
#        date  game_number  day visitor visitor_lg  visitor_game_number home  \
# 0  19990404            0  Sun     COL         NL                    1  SDN
# 1  19990405            0  Mon     TBA         AL                    1  BAL
# 2  19990405            0  Mon     BOS         AL                    1  KCA
# 3  19990405            0  Mon     NYA         AL                    1  OAK
# 4  19990405            0  Mon     CHA         AL                    1  SEA
#
#   home_lg  home_game_number  visitor_score  ...  home_batter_7_pos  \
# 0      NL                 1              8  ...                  8
# 1      AL                 1              7  ...                  7
# 2      AL                 1              5  ...                  2
# 3      AL                 1              3  ...                  5
# 4      AL                 1              8  ...                  7
#
#    home_batter_8_id home_batter_8_name home_batter_8_pos  home_batter_9_id  \
# 0          gomec001        Chris Gomez                 6          ashba002
# 1          johnc002    Charles Johnson                 2          reboj001
# 2          sancr001        Rey Sanchez                 6          feblc001
# 3          hinca001         A.J. Hinch                 2          tejam001
# 4          davir002         Russ Davis                 5          wilsd001
#
#   home_batter_9_name home_batter_9_pos  additional_info  acquisition  Year
# 0         Andy Ashby                 1              NaN            Y  1999
# 1      Jeff Reboulet                 4              NaN            Y  1999
# 2      Carlos Febles                 4              NaN            Y  1999
# 3      Miguel Tejada                 6              NaN            Y  1999
# 4         Dan Wilson                 2              NaN            Y  1999
#
# [5 rows x 162 columns]

# %%
Teams['home_win'] = np.where(Teams['home_score']>Teams['visitor_score'],1,0)
Teams['away_win'] = np.where(Teams['home_score']>Teams['visitor_score'],0,1)
Teams.head(15)
# Out:
#         date  game_number  day visitor visitor_lg  visitor_game_number home  \
# 0   19990404            0  Sun     COL         NL                    1  SDN
# 1   19990405            0  Mon     TBA         AL                    1  BAL
# 2   19990405            0  Mon     BOS         AL                    1  KCA
# 3   19990405            0  Mon     NYA         AL                    1  OAK
# 4   19990405            0  Mon     CHA         AL                    1  SEA
# 5   19990405            0  Mon     DET         AL                    1  TEX
# 6   19990405            0  Mon     PHI         NL                    1  ATL
# 7   19990405            0  Mon     SFN         NL                    1  CIN
# 8   19990405            0  Mon     NYN         NL                    1  FLO
# 9   19990405            0  Mon     ARI         NL                    1  LAN
# 10  19990405            0  Mon     MON         NL                    1  PIT
# 11  19990405            0  Mon     MIL         NL                    1  SLN
# 12  19990406            0  Tue     CLE         AL                    1  ANA
# 13  19990406            0  Tue     TOR         AL                    1  MIN
# 14  19990406            0  Tue     NYA         AL                    2  OAK
#
#    home_lg  home_game_number  visitor_score  ...  home_batter_8_name  \
# 0       NL                 1              8  ...         Chris Gomez
# 1       AL                 1              7  ...     Charles Johnson
# 2       AL                 1              5  ...         Rey Sanchez
# 3       AL                 1              3  ...          A.J. Hinch
# 4       AL                 1              8  ...          Russ Davis
# 5       AL                 1             11  ...          Todd Zeile
# 6       NL                 1              7  ...          Walt Weiss
# 7       NL                 1             11  ...         Pokey Reese
# 8       NL                 1              2  ...        Mike Redmond
# 9       NL                 1              6  ...       Adrian Beltre
# 10      NL                 1              9  ...       Mike Benjamin
# 11      NL                 1             10  ...     Placido Polanco
# 12      AL                 1              5  ...        Matt Walbeck
# 13      AL                 1              1  ...     Terry Steinbach
# 14      AL                 2              7  ...          A.J. Hinch
#
#     home_batter_8_pos home_batter_9_id home_batter_9_name  home_batter_9_pos  \
# 0                   6         ashba002         Andy Ashby                  1
# 1                   2         reboj001      Jeff Reboulet                  4
# 2                   6         feblc001      Carlos Febles                  4
# 3                   2         tejam001      Miguel Tejada                  6
# 4                   5         wilsd001         Dan Wilson                  2
# 5                   5         clayr001      Royce Clayton                  6
# 6                   6         glavt001        Tom Glavine                  1
# 7                   4         tomkb001        Brett Tomko                  1
# 8                   2         ferna001     Alex Fernandez                  1
# 9                   5         browk001        Kevin Brown                  1
# 10                  6         cordf001  Francisco Cordova                  1
# 11                  4         osbod001    Donovan Osborne                  1
# 12                  2         sheea001        Andy Sheets                  6
# 13                  2         guzmc001    Cristian Guzman                  6
# 14                  2         tejam001      Miguel Tejada                  6
#
#    additional_info acquisition  Year  home_win away_win
# 0              NaN           Y  1999         0        1
# 1              NaN           Y  1999         1        0
# 2              NaN           Y  1999         0        1
# 3              NaN           Y  1999         1        0
# 4              NaN           Y  1999         0        1
# 5              NaN           Y  1999         0        1
# 6              NaN           Y  1999         0        1
# 7              NaN           Y  1999         0        1
# 8              NaN           Y  1999         1        0
# 9              NaN           Y  1999         1        0
# 10             NaN           Y  1999         0        1
# 11             NaN           Y  1999         0        1
# 12             NaN           Y  1999         1        0
# 13             NaN           Y  1999         1        0
# 14             NaN           Y  1999         0        1
#
# [15 rows x 164 columns]

# %% [markdown]
# 각 팀의 Home 경기, Away 경기 grouping

# %%
### 계산에 필요한 columns =
### ['visitor_ab', 'visitor_h', 'visitor_2b', 'visitor_3b', 'visitor_hr', 'visitor_sf',
### 'visitor_hbp','visitor_bb','home_ab', 'home_h', 'home_2b', 'home_3b',
### 'home_hr', 'home_sf', 'home_hbp', 'home_bb', 'home_win','away_win']

Home_team = Teams.groupby(['Year','home'])['visitor_ab', 'visitor_h', 'visitor_2b', 'visitor_3b', 'visitor_hr', 'visitor_sf',
                                           'visitor_hbp','visitor_bb','home_ab', 'home_h', 'home_2b', 'home_3b',
                                           'home_hr', 'home_sf', 'home_hbp', 'home_bb', 'home_win','away_win'].sum()
Home_team = Home_team.reset_index()

# 총 30팀
Home_team.head(30)
# Out:
# <ipython-input-7-a450153cb380>:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Home_team = Teams.groupby(['Year','home'])['visitor_ab', 'visitor_h', 'visitor_2b', 'visitor_3b', 'visitor_hr', 'visitor_sf',
#     Year home  visitor_ab  visitor_h  visitor_2b  visitor_3b  visitor_hr  \
# 0   1999  ANA        2832        762         151          10         105
# 1   1999  ARI        2814        693         132          22          84
# 2   1999  ATL        2798        674         107          10          75
# 3   1999  BAL        2827        760         112          15         101
# 4   1999  BOS        2820        722         149          10          72
# 5   1999  CHA        2934        826         140           4         106
# 6   1999  CHN        2929        855         144          15         124
# 7   1999  CIN        2798        671         164          10         116
# 8   1999  CLE        2912        806         168          14         109
# 9   1999  COL        3005        987         181          26         159
# 10  1999  DET        2820        758         138          16         117
# 11  1999  FLO        2812        747         142          24          75
# 12  1999  HOU        2832        718         136          21          53
# 13  1999  KCA        2854        831         122          17          96
# 14  1999  LAN        2821        706         123           7         102
# 15  1999  MIL        2894        830         129          15         110
# 16  1999  MIN        2940        828         194          16         109
# 17  1999  MON        2844        765         166          16          68
# 18  1999  NYA        2782        671         132          10          74
# 19  1999  NYN        2772        699         151          25          77
# 20  1999  OAK        2833        741         159          12          74
# 21  1999  PHI        2827        730         150          12         108
# 22  1999  PIT        2778        706         153          14          80
# 23  1999  SDN        2774        694         122          10          90
# 24  1999  SEA        2888        828         180          10         105
# 25  1999  SFN        2845        705         120           8          98
# 26  1999  SLN        2866        772         155          11          83
# 27  1999  TBA        2892        839         179          20          91
# 28  1999  TEX        2928        846         166          20         109
# 29  1999  TOR        2891        817         190          11          93
#
#     visitor_sf  visitor_hbp  visitor_bb  home_ab  home_h  home_2b  home_3b  \
# 0           39           27         322     2666     669      118       13
# 1           16           27         256     2730     754      142       31
# 2           19           10         221     2668     704      158        9
# 3           27           30         329     2732     762      136        9
# 4           20           32         226     2722     793      177       20
# 5           30           30         281     2726     740      137       20
# 6           37           15         267     2707     730      140       22
# 7           16           23         326     2734     726      147       15
# 8           21           20         328     2752     819      137       16
# 9           26           32         385     2938     955      174       26
# 10          32           31         295     2694     712      130       22
# 11          36           30         319     2745     716      132       26
# 12          23           23         234     2688     702      155       14
# 13          26           29         313     2771     804      140       33
# 14          18           34         274     2702     728      113        9
# 15          23           28         289     2703     741      136       12
# 16          22           11         267     2732     735      161       19
# 17          24           26         277     2732     742      182       23
# 18          20           29         293     2683     730      135       14
# 19          26           32         326     2690     714      120        5
# 20          19           32         284     2662     711      146       12
# 21          13           27         333     2754     761      160       25
# 22          23           30         304     2662     707      150       22
# 23          25           17         250     2660     705      117       17
# 24          27           29         330     2721     742      139        8
# 25          11           18         312     2683     703      139        8
# 26          19           28         344     2731     711      117       11
# 27          31           42         338     2700     722      123       13
# 28          28           24         240     2756     837      151       20
# 29          31           25         289     2731     765      173        6
#
#     home_hr  home_sf  home_hbp  home_bb  home_win  away_win
# 0        74       21        23      267        37        44
# 1       101       31        17      285        52        29
# 2        86       28        22      286        56        25
# 3        98       32        36      315        41        40
# 4        80       29        30      305        49        32
# 5        77       19        14      247        38        43
# 6        98       25        17      294        34        47
# 7        97       24        19      298        45        37
# 8       110       33        19      370        47        34
# 9       144       30        23      269        39        42
# 10      118       20        40      239        38        43
# 11       48       29        28      268        35        45
# 12       65       24        31      366        50        32
# 13       74       26        35      269        33        47
# 14       92       29        26      285        37        44
# 15       77       17        32      327        32        48
# 16       47       29        24      258        31        50
# 17       84       17        27      230        35        46
# 18       84       17        26      364        48        33
# 19       84       23        23      321        49        32
# 20      112       23        33      371        52        29
# 21       77       15        21      342        41        40
# 22       91       26        29      290        45        36
# 23       69       22        13      333        46        35
# 24      122       29        24      317        43        38
# 25       87       21        31      338        49        32
# 26      104       21        23      304        38        42
# 27       66       25        37      277        33        48
# 28      103       30        21      321        51        30
# 29       96       21        44      283        40        41

# %%
Away_team = Teams.groupby(['Year','visitor'])['visitor_ab', 'visitor_h', 'visitor_2b', 'visitor_3b', 'visitor_hr', 'visitor_sf',
                                           'visitor_hbp','visitor_bb','home_ab', 'home_h', 'home_2b', 'home_3b',
                                           'home_hr', 'home_sf', 'home_hbp', 'home_bb', 'home_win','away_win'].sum()
Away_team = Away_team.reset_index()
# Out:
# <ipython-input-8-8fbf1b504692>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Away_team = Teams.groupby(['Year','visitor'])['visitor_ab', 'visitor_h', 'visitor_2b', 'visitor_3b', 'visitor_hr', 'visitor_sf',

# %% [markdown]
# Home 경기, Away 경기 합치기 = Teams2

# %%
Home_team = Home_team.rename(columns={'home': 'Team'})
Away_team = Away_team.rename(columns={'visitor': 'Team'})

Teams2 = pd.merge(Home_team, Away_team, on=['Team','Year'])

# %%
Teams2.head(30)
# Out:
#     Year Team  visitor_ab_x  visitor_h_x  visitor_2b_x  visitor_3b_x  \
# 0   1999  ANA          2832          762           151            10
# 1   1999  ARI          2814          693           132            22
# 2   1999  ATL          2798          674           107            10
# 3   1999  BAL          2827          760           112            15
# 4   1999  BOS          2820          722           149            10
# 5   1999  CHA          2934          826           140             4
# 6   1999  CHN          2929          855           144            15
# 7   1999  CIN          2798          671           164            10
# 8   1999  CLE          2912          806           168            14
# 9   1999  COL          3005          987           181            26
# 10  1999  DET          2820          758           138            16
# 11  1999  FLO          2812          747           142            24
# 12  1999  HOU          2832          718           136            21
# 13  1999  KCA          2854          831           122            17
# 14  1999  LAN          2821          706           123             7
# 15  1999  MIL          2894          830           129            15
# 16  1999  MIN          2940          828           194            16
# 17  1999  MON          2844          765           166            16
# 18  1999  NYA          2782          671           132            10
# 19  1999  NYN          2772          699           151            25
# 20  1999  OAK          2833          741           159            12
# 21  1999  PHI          2827          730           150            12
# 22  1999  PIT          2778          706           153            14
# 23  1999  SDN          2774          694           122            10
# 24  1999  SEA          2888          828           180            10
# 25  1999  SFN          2845          705           120             8
# 26  1999  SLN          2866          772           155            11
# 27  1999  TBA          2892          839           179            20
# 28  1999  TEX          2928          846           166            20
# 29  1999  TOR          2891          817           190            11
#
#     visitor_hr_x  visitor_sf_x  visitor_hbp_x  visitor_bb_x  ...  home_ab_y  \
# 0            105            39             27           322  ...       2645
# 1             84            16             27           256  ...       2751
# 2             75            19             10           221  ...       2772
# 3            101            27             30           329  ...       2638
# 4             72            20             32           226  ...       2704
# 5            106            30             30           281  ...       2766
# 6            124            37             15           267  ...       2729
# 7            116            16             23           326  ...       2626
# 8            109            21             20           328  ...       2694
# 9            159            26             32           385  ...       2643
# 10           117            32             31           295  ...       2714
# 11            75            36             30           319  ...       2730
# 12            53            23             23           234  ...       2740
# 13            96            26             29           313  ...       2725
# 14           102            18             34           274  ...       2750
# 15           110            23             28           289  ...       2811
# 16           109            22             11           267  ...       2681
# 17            68            24             26           277  ...       2721
# 18            74            20             29           293  ...       2724
# 19            77            26             32           326  ...       2682
# 20            74            19             32           284  ...       2780
# 21           108            13             27           333  ...       2723
# 22            80            23             30           304  ...       2706
# 23            90            25             17           250  ...       2695
# 24           105            27             29           330  ...       2739
# 25            98            11             18           312  ...       2769
# 26            83            19             28           344  ...       2696
# 27            91            31             42           338  ...       2718
# 28           109            28             24           240  ...       2750
# 29            93            31             25           289  ...       2753
#
#     home_h_y  home_2b_y  home_3b_y  home_hr_y  home_sf_y  home_hbp_y  \
# 0        710        134         15         72         26          29
# 1        694        123         12         92         14          22
# 2        724        131          9         67         22          16
# 3        708        157         19         97         22          19
# 4        674        134         10         88         23          23
# 5        782        136         14        104         26          31
# 6        764        133         26         97         29          12
# 7        638        138         13         74         27          22
# 8        697        131         16         88         18          34
# 9        713        145         15         78         26          28
# 10       770        145         12         92         28          39
# 11       813        148         16         96         33          24
# 12       767        135         14         75         26          17
# 13       776        132         16        106         27          39
# 14       732        152         19         90         16          28
# 15       788        150         19        103         21          23
# 16       763        128         19         99         26          17
# 17       740        145         12         84         26          34
# 18       731        140         18         84         27          28
# 19       673        147         30         90         25          20
# 20       796        168         19         86         20          22
# 21       764        149         15        104         31          31
# 22       738        156         21         80         22          21
# 23       760        131         19        103         19          18
# 24       785        142         14         86         27          42
# 25       781        150         11         96         28          33
# 26       747        147         25         78         29          35
# 27       767        145         11         81         22          37
# 28       780        178         19         77         24          16
# 29       765        135         22         98         26          28
#
#     home_bb_y  home_win_y  away_win_y
# 0         302          48          33
# 1         287          33          48
# 2         286          34          47
# 3         318          44          37
# 4         243          36          45
# 5         315          44          37
# 6         262          48          33
# 7         310          30          51
# 8         306          31          50
# 9         352          48          33
# 10        288          49          31
# 11        336          53          29
# 12        244          33          47
# 13        330          50          31
# 14        320          41          40
# 15        327          39          42
# 16        220          47          33
# 17        295          48          33
# 18        288          31          50
# 19        291          34          48
# 20        285          46          35
# 21        294          45          36
# 22        329          47          33
# 23        279          53          28
# 24        354          45          36
# 25        343          44          37
# 26        323          44          37
# 27        357          45          36
# 28        269          37          44
# 29        286          37          44
#
# [30 rows x 38 columns]

# %% [markdown]
#     각 팀의 승리 = Home 경기의 home 팀 승리 (home_win_x) + Away 경기의 away 팀 승리 (away_win_y)
#     경기 수 = Home 경기의 home_win 데이터 count + Away 경기의 away_win 데이터 count
#     승률 = 승리/경기 수
#
#     OBP = (h + bb + hbp)/(ab + bb + hbp + sf)
#     SLG = (h - 2b - 3b - hr +2(2b) + 3(3b) + 4(hr)) /ab
#
#     각 데이터 => Home 경기의 home 팀 데이터 + Away 경기의 away 팀 데이터

# %%
# 총 경기 수 계산

Home_game = Teams.groupby(['Year', 'home'])['home_win'].count()
Home_game = Home_game.reset_index()
Away_game = Teams.groupby(['Year', 'visitor'])['away_win'].count()
Away_game = Away_game.reset_index()
Home_game = Home_game.rename(columns={'home': 'Team'})
Away_game = Away_game.rename(columns={'visitor': 'Team'})

total_game = pd.merge(Home_game, Away_game, on=['Team','Year'])
total_game['Total'] = total_game['home_win'] + total_game['away_win']
Total = total_game[['Year','Team','Total']]
Total
# Out:
#      Year Team  Total
# 0    1999  ANA    162
# 1    1999  ARI    162
# 2    1999  ATL    162
# 3    1999  BAL    162
# 4    1999  BOS    162
# ..    ...  ...    ...
# 145  2003  SFN    161
# 146  2003  SLN    162
# 147  2003  TBA    162
# 148  2003  TEX    162
# 149  2003  TOR    162
#
# [150 rows x 3 columns]

# %%
# 승리 수, OBP, SLG 계산

Teams2['W'] = Teams2['home_win_x'] + Teams2['away_win_y']
Teams2['OBP'] = ((Teams2['home_h_x']+Teams2['visitor_h_y']+
                Teams2['home_bb_x']+Teams2['visitor_bb_y']+
                Teams2['home_hbp_x']+Teams2['visitor_hbp_y'])/
                (Teams2['home_ab_x']+Teams2['visitor_ab_y']+
                 Teams2['home_bb_x']+Teams2['visitor_bb_y']+
                 Teams2['home_hbp_x']+Teams2['visitor_hbp_y']+
                 Teams2['home_sf_x']+Teams2['visitor_sf_y']))
Teams2['SLG'] = ((Teams2['home_h_x']+Teams2['visitor_h_y']-
                (Teams2['home_2b_x']+Teams2['visitor_2b_y'])-
                (Teams2['home_3b_x']+Teams2['visitor_3b_y'])-
                (Teams2['home_hr_x']+Teams2['visitor_hr_y'])+
                2*Teams2['home_2b_x']+2*Teams2['visitor_2b_y']+
                3*Teams2['home_3b_x']+3*Teams2['visitor_3b_y']+
                4*Teams2['home_hr_x']+4*Teams2['visitor_hr_y'])/
                (Teams2['home_ab_x']+Teams2['visitor_ab_y']))

# %%
Teams2.head()
# Out:
#    Year Team  visitor_ab_x  visitor_h_x  visitor_2b_x  visitor_3b_x  \
# 0  1999  ANA          2832          762           151            10
# 1  1999  ARI          2814          693           132            22
# 2  1999  ATL          2798          674           107            10
# 3  1999  BAL          2827          760           112            15
# 4  1999  BOS          2820          722           149            10
#
#    visitor_hr_x  visitor_sf_x  visitor_hbp_x  visitor_bb_x  ...  home_3b_y  \
# 0           105            39             27           322  ...         15
# 1            84            16             27           256  ...         12
# 2            75            19             10           221  ...          9
# 3           101            27             30           329  ...         19
# 4            72            20             32           226  ...         10
#
#    home_hr_y  home_sf_y  home_hbp_y  home_bb_y  home_win_y  away_win_y    W  \
# 0         72         26          29        302          48          33   70
# 1         92         14          22        287          33          48  100
# 2         67         22          16        286          34          47  103
# 3         97         22          19        318          44          37   78
# 4         88         23          23        243          36          45   94
#
#         OBP       SLG
# 0  0.321511  0.394976
# 1  0.346553  0.458643
# 2  0.341246  0.435805
# 3  0.353015  0.447401
# 4  0.350406  0.447571
#
# [5 rows x 41 columns]

# %%
Teams3 = Teams2[['Year', 'Team', 'W', 'OBP', 'SLG']]
Teams3 = pd.merge(Teams3, Total, on=['Team', 'Year'])
Teams3['WPC'] = Teams3['W'] / Teams3['Total']
Teams3
# Out:
#      Year Team    W       OBP       SLG  Total       WPC
# 0    1999  ANA   70  0.321511  0.394976    162  0.432099
# 1    1999  ARI  100  0.346553  0.458643    162  0.617284
# 2    1999  ATL  103  0.341246  0.435805    162  0.635802
# 3    1999  BAL   78  0.353015  0.447401    162  0.481481
# 4    1999  BOS   94  0.350406  0.447571    162  0.580247
# ..    ...  ...  ...       ...       ...    ...       ...
# 145  2003  SFN  100  0.338283  0.425037    161  0.621118
# 146  2003  SLN   85  0.350055  0.453808    162  0.524691
# 147  2003  TBA   63  0.319903  0.404316    162  0.388889
# 148  2003  TEX   71  0.330037  0.453566    162  0.438272
# 149  2003  TOR   86  0.348812  0.454513    162  0.530864
#
# [150 rows x 7 columns]

# %% [markdown]
# # Regression

# %%
import statsmodels.formula.api as smf
import seaborn as sns

# %%
sns.lmplot(x='OBP', y='WPC', data=Teams3)
plt.xlabel('OBP')
plt.ylabel('Winning Percent')
plt.title('Relationship betwwen OBP and Winning Percent')
# Out:
# Text(0.5, 1.0, 'Relationship betwwen OBP and Winning Percent')

# %%
reg_obp = smf.ols(formula = 'WPC ~ OBP', data=Teams3).fit()
reg_obp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WPC   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.378
# Method:                 Least Squares   F-statistic:                     91.63
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):           3.42e-17
# Time:                        21:03:38   Log-Likelihood:                 206.51
# No. Observations:                 150   AIC:                            -409.0
# Df Residuals:                     148   BIC:                            -403.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6435      0.120     -5.382      0.000      -0.880      -0.407
# OBP            3.3942      0.355      9.572      0.000       2.694       4.095
# ==============================================================================
# Omnibus:                        2.506   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.286   Jarque-Bera (JB):                2.466
# Skew:                           0.257   Prob(JB):                        0.291
# Kurtosis:                       2.639   Cond. No.                         78.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.lmplot(x='SLG', y='WPC', data=Teams3)
plt.xlabel('SLG')
plt.ylabel('Winning Percent')
plt.title('Relationship betwwen SLG and Winning Percent')
# Out:
# Text(0.5, 1.0, 'Relationship betwwen SLG and Winning Percent')

# %%
reg_slg = smf.ols(formula = 'WPC ~ SLG', data=Teams3).fit()
reg_slg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WPC   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     60.33
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):           1.23e-12
# Time:                        21:03:39   Log-Likelihood:                 196.01
# No. Observations:                 150   AIC:                            -388.0
# Df Residuals:                     148   BIC:                            -382.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1978      0.090     -2.197      0.030      -0.376      -0.020
# SLG            1.6338      0.210      7.767      0.000       1.218       2.049
# ==============================================================================
# Omnibus:                        1.266   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.531   Jarque-Bera (JB):                1.336
# Skew:                           0.165   Prob(JB):                        0.513
# Kurtosis:                       2.677   Cond. No.                         46.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True)
plt.ylim(0,1)
sns.regplot(x='SLG', y='WPC', data=Teams3, ax=ax1)
sns.regplot(x='OBP', y='WPC', data=Teams3, ax=ax2)
# Out:
# <AxesSubplot:xlabel='OBP', ylabel='WPC'>

# %% [markdown]
# ## 해석
#
# 팀의 승률과의 회귀계수가
# OBP의 경우 3.394,
# SLG의 경우 1.634
# (p값이 둘 다 0.05보다 작기 때문에 통계적으로 유의함)
#
# 팀 전체 OBP가 0.01 차이날 때, 승률이 약 0.034 차이난다
# 팀 전체 SLG가 0.01 차이날 때, 승률이 약 0.016 차이난다
#
# OBP가 SLG보다 더 팀의 승률을 높이는데 기여한다
